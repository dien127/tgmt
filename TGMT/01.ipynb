# %%
# Shift + Enter: run code + add row

# %%
# Cài đặt
# !pip install Pillow
# !conda install Pillow

# %%
# Import lớp Image
from PIL import Image

# %%
# Thư mục chứa hình ảnh
dir = r'D:/img'

# %%
# Đường dẫn đến hình ảnh
image_path = dir + r'/mot.jpg'
print(image_path)
# Out:
# D:/img/mot.jpg

# %%
# Sử dụng Image.open() đọc ảnh
img1 = Image.open(image_path)

# %%
# Hiển thị hình ảnh
display(img1)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=750x562>

# %%
# In một số thông tin
# In định dạng ảnh
print("Định dạng ảnh: ", img01.format)
# Out:
# Định dạng ảnh:  JPEG

# %%
# In ra size
print("Kích thước hình ảnh: ", img01.size)
# Out:
# Kích thước hình ảnh:  (750, 562)

# %%
#Lưu ảnh và chuyển đổi ảnh
new_img_01_path = dir + '/new_01.jpg'
new_img_png_01_path = dir + '/new_01.png'
img01.save(new_img_01_path)
img01.save(new_img_png_01_path)

# %%
# Đóng tập tin
img01.close()
